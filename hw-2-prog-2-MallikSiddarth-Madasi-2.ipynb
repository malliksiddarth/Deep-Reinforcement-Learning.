# %%
pip install keract
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import tensorflow as tf
import matplotlib.pyplot as pl
import numpy
from tensorflow import keras
from tensorflow.keras import Sequential
from math import sin, pi
from keras.layers import Activation, Dense

# %%
x=numpy.arange(-2,2,0.02)
trainx=x.reshape(200,1)
y=numpy.sin(pi/4*trainx)
trainy=y.reshape(200,1)

testx=numpy.arange(-2,2,0.02)
y=numpy.sin(pi/4*testx)
testy=y.reshape(200,1)
pl.plot(trainx, trainy)
pl.show()
input_shape= (1,)

# %%
model=tf.keras.models.Sequential()
model.add(tf.keras.layers.Dense(1,input_shape=input_shape))
model.add(tf.keras.layers.Dense(12, activation='relu'))
model.add(tf.keras.layers.Dense(1, activation='linear'))
model.compile(optimizer='adam', loss='mean_absolute_error', metrics=['mae'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 1)                 2
#
#  dense_1 (Dense)             (None, 12)                24
#
#  dense_2 (Dense)             (None, 1)                 13
#
# ...
# Total params: 39
# Trainable params: 39
# Non-trainable params: 0
# _________________________________________________________________

# %%
his=model.fit(trainx,trainy, epochs=500, batch_size=20,  validation_split=0.2)
from keract import get_activations,display_activations
input=testx
target=testy
activations=get_activations(model,input)
#display_activations(activations,cmap='gray',save=False)
# Out:
# Epoch 1/500
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0050 - mae: 0.0050 - val_loss: 0.1790 - val_mae: 0.1790
# Epoch 2/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0047 - mae: 0.0047 - val_loss: 0.1790 - val_mae: 0.1790
# Epoch 3/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0050 - mae: 0.0050 - val_loss: 0.1791 - val_mae: 0.1791
# Epoch 4/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0048 - mae: 0.0048 - val_loss: 0.1790 - val_mae: 0.1790
# Epoch 5/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0053 - mae: 0.0053 - val_loss: 0.1787 - val_mae: 0.1787
# Epoch 6/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0050 - mae: 0.0050 - val_loss: 0.1789 - val_mae: 0.1789
# Epoch 7/500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0048 - mae: 0.0048 - val_loss: 0.1793 - val_mae: 0.1793
# Epoch 8/500
# ...

# %%
def plot_loss(his):
    pl.plot(trainx,model.predict(trainx), label='predicted values')
    pl.plot(trainx,trainy, label='original values')
    pl.legend()
    pl.show()
    pl.plot(trainx,numpy.absolute(trainy-model.predict(trainx)))
    pl.grid()
plot_loss(his)

# %%
import matplotlib.pyplot as plt
mae = his.history['mae']
val_mae = his.history['val_mae']
loss = his.history['loss']
val_loss = his.history['val_loss']
epochs = range(len(mae))
plt.plot(epochs, mae, 'b', label='mae')
plt.plot(epochs, val_mae, 'r', label='val mae')
plt.ylabel('Error')
plt.xlabel('Epoch')
plt.title('Training Error')
plt.legend()
plt.show()

# %%
from scipy.spatial.distance import hamming
x=his.history['mae'][0]
y=his.history['mae'][-1]
result=hamming(x,y)
print(result)
# Out:
# 1.0

# %%
result=0
r=[]
for j in range(len(his.history['mae'])-1):
    result = hamming(his.history['mae'][j],his.history['mae'][j+1])
    r.append(result)

# %%
import matplotlib.pyplot as plt
mae = his.history['mae']
epochs = range(len(mae))
plt.plot(epochs, mae, 'b', label='Training mae')
plt.plot(r, label='hamming values')
plt.ylabel('Error')
plt.xlabel('Epoch')
plt.title('Hamming Distance ')
plt.legend()
plt.show()
